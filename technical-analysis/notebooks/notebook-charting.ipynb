// %%
%use kandy

// %%
import gan.stockbot.api.auth.AuthToken
val authToken = AuthToken("", "")

// %%
import org.jetbrains.kotlinx.kandy.dsl.plot
import org.jetbrains.kotlinx.kandy.letsplot.layers.bars

plot {
    bars {
        x(listOf("first", "second", "third"))
        y(listOf(7, 3, 5))
    }
}
// Out:
// Plot(datasets=[NamedData(dataFrame=
// ), NamedData(dataFrame=        x y
//  0  first 7
//  1 second 3
//  2  third 5
// )], layers=[Layer(datasetIndex=1, geom=LetsPlotGeom(name=bar), mappings={Aes(name=x)=PositionalMapping(aes=Aes(name=x), columnID=x, parameters=LetsPlotPositionalMappingParametersContinuous(scale=org.jetbrains.kotlinx.kandy.ir.scale.PositionalDefaultScale@62c59ee9, axis=Axis(name=null, position=DEFAULT, min=null, max=null, breaks=null, labels=null, format=null, expand=null))), Aes(name=y)=PositionalMapping(aes=Aes(name=y), columnID=y, parameters=LetsPlotPositionalMappingParametersContinuous(scale=org.jetbrains.kotlinx.kandy.ir.scale.PositionalDefaultScale@62c59ee9, axis=Axis(name=null, position=DEFAULT, min=null, max=null, breaks=null, labels=null, format=null, expand=null)))}, settings={}, features={FeatureName(name=POSITION)=Dodge(width=null)}, freeScales={}, inheritsBindings=false)], globalMappings={}, globalSettings={}, features={}, freeScales={})
